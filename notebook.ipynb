# %% [markdown]
# # Data Analyst Professional Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %% [markdown]
# ## 📝 Task List
#
# Your written report should include written text summaries and graphics of the following:
# - Data validation:
#   - Describe validation and cleaning steps for every column in the data
# - Exploratory Analysis:
#   - Include two different graphics showing single variables only to demonstrate the characteristics of data
#   - Include at least one graphic showing two or more variables to represent the relationship between features
#   - Describe your findings
# - Definition of a metric for the business to monitor
#   - How should the business use the metric to monitor the business problem
#   - Can you estimate initial value(s) for the metric based on the current data
# - Final summary including recommendations that the business should undertake
#
# *Start writing report here..*

# %% [markdown]
# ## ✅ When you have finished...
# -  Publish your Workspace using the option on the left
# -  Check the published version of your report:
# 	-  Can you see everything you want us to grade?
#     -  Are all the graphics visible?
# -  Review the grading rubric. Have you included everything that will be graded?
# -  Head back to the [Certification Dashboard](https://app.datacamp.com/certification) to submit your practical exam report and record your presentation

# %% [markdown]
# First I need to load all the packages into R  from the library that I will use. I plan to use:
# - readr
# - dplyr
# - ggplot2
# - tidyr

# %%
library (readr)
library (dplyr)
library (ggplot2)
library (stringr)
library (tidyr)

# %% [markdown]
# Next I will import the data using the read_scv function from readr. I will save it as a data frame named sales_raw. This will allow me to more easily refer to the data

# %%
sales_raw <- read_csv("product_sales.csv")

sales_raw
# Out:
# Rows: 15000 Columns: 8
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): sales_method, customer_id, state
# dbl (5): week, nb_sold, revenue, years_as_customer, nb_site_visits
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#       week sales_method customer_id                          nb_sold revenue
# 1     2    Email        2e72d641-95ac-497b-bbf8-4861764a7097 10          NA
# 2     6    Email + Call 3998a98d-70f5-44f7-942e-789bb8ad2fe7 15      225.47
# 3     5    Call         d1de9884-8059-4065-b10f-86eef57e4a44 11       52.55
# 4     4    Email        78aa75a4-ffeb-4817-b1d0-2f030783c5d7 11          NA
# 5     3    Email        10e6d446-10a5-42e5-8210-1b5438f70922  9       90.49
# 6     6    Call         6489e678-40f2-4fed-a48e-d0dff9c09205 13       65.01
# ...

# %% [markdown]
# Next I want to confirm that the structure of the data matches the structures described in the instructions. I will do this using str()

# %%
str(sales_raw)
# Out:
# spc_tbl_ [15,000 × 8] (S3: spec_tbl_df/tbl_df/tbl/data.frame)
#  $ week             : num [1:15000] 2 6 5 4 3 6 4 1 5 5 ...
#  $ sales_method     : chr [1:15000] "Email" "Email + Call" "Call" "Email" ...
#  $ customer_id      : chr [1:15000] "2e72d641-95ac-497b-bbf8-4861764a7097" "3998a98d-70f5-44f7-942e-789bb8ad2fe7" "d1de9884-8059-4065-b10f-86eef57e4a44" "78aa75a4-ffeb-4817-b1d0-2f030783c5d7" ...
#  $ nb_sold          : num [1:15000] 10 15 11 11 9 13 11 10 11 11 ...
#  $ revenue          : num [1:15000] NA 225.5 52.5 NA 90.5 ...
#  $ years_as_customer: num [1:15000] 0 1 6 3 0 10 9 1 10 7 ...
#  $ nb_site_visits   : num [1:15000] 24 28 26 25 28 24 28 22 31 23 ...
#  $ state            : chr [1:15000] "Arizona" "Kansas" "Wisconsin" "Indiana" ...
#  - attr(*, "spec")=
#   .. cols(
#   ..   week = col_double(),
#   ..   sales_method = col_character(),
#   ..   customer_id = col_character(),
#   ..   nb_sold = col_double(),
#   ..   revenue = col_double(),
# ...

# %% [markdown]
# All the columns have the structure listed in the instructions.
#
# Next I just want to view the first few lines of the table and the last few lines of the table to see what the data looks like.

# %%
# view the first few rows
head(sales_raw)

# view the last few rows
tail(sales_raw)
# Out:
#   week sales_method customer_id                          nb_sold revenue
# 1 2    Email        2e72d641-95ac-497b-bbf8-4861764a7097 10          NA
# 2 6    Email + Call 3998a98d-70f5-44f7-942e-789bb8ad2fe7 15      225.47
# 3 5    Call         d1de9884-8059-4065-b10f-86eef57e4a44 11       52.55
# 4 4    Email        78aa75a4-ffeb-4817-b1d0-2f030783c5d7 11          NA
# 5 3    Email        10e6d446-10a5-42e5-8210-1b5438f70922  9       90.49
# 6 6    Call         6489e678-40f2-4fed-a48e-d0dff9c09205 13       65.01
#   years_as_customer nb_site_visits state
# 1  0                24             Arizona
# 2  1                28             Kansas
# 3  6                26             Wisconsin
# 4  3                25             Indiana
# 5  0                28             Illinois
# 6 10                24             Mississippi
#   week sales_method customer_id                          nb_sold revenue
# 1 4    Email        56f02e26-3633-427d-8c4e-f45f00afa787 11      109.36
# ...

# %% [markdown]
# Looking at the first and last few rows of the table I can see that there as some rows with "Invalid" as the revenue type. I will either need to impute these values or exclude them from the dataset. However first I want to change the column sale_method into a fasctor using as.factor. This will allow for easier visualization later. I am going to save the dataframe as a new dataframe called sales_clean so I can mantain a raw dataframe if I need to troubleshoot.

# %%
#convert sale_method into a factor
sales_clean<- sales_raw %>%
mutate(sales_method= as.factor(sales_method))

##Next confirm all rows are present and have the proper structure
str(sales_clean)
# Out:
# tibble [15,000 × 8] (S3: tbl_df/tbl/data.frame)
#  $ week             : num [1:15000] 2 6 5 4 3 6 4 1 5 5 ...
#  $ sales_method     : Factor w/ 5 levels "Call","em + call",..: 4 5 1 4 4 1 4 4 4 1 ...
#  $ customer_id      : chr [1:15000] "2e72d641-95ac-497b-bbf8-4861764a7097" "3998a98d-70f5-44f7-942e-789bb8ad2fe7" "d1de9884-8059-4065-b10f-86eef57e4a44" "78aa75a4-ffeb-4817-b1d0-2f030783c5d7" ...
#  $ nb_sold          : num [1:15000] 10 15 11 11 9 13 11 10 11 11 ...
#  $ revenue          : num [1:15000] NA 225.5 52.5 NA 90.5 ...
#  $ years_as_customer: num [1:15000] 0 1 6 3 0 10 9 1 10 7 ...
#  $ nb_site_visits   : num [1:15000] 24 28 26 25 28 24 28 22 31 23 ...
#  $ state            : chr [1:15000] "Arizona" "Kansas" "Wisconsin" "Indiana" ...

# %% [markdown]
# Converting sales_method into a factor revealed there are 5 factor groups when there should only be 3. I am going to see what these groups are and how many are there by counting the number of enteries and grouping by sales_method.

# %%
sales_clean %>%
count(sales_method) %>%
group_by (sales_method)
# Out:
# New names:
# • `` -> `...1`
#   sales_method n
# 1 Call         4962
# 2 em + call      23
# 3 email          10
# 4 Email        7456
# 5 Email + Call 2549

# %% [markdown]
# We can see that there is a sales_method "email" and another "Email". These can be combined by using the the str_to_title function from stringr

# %%
#Convert the first letter of each word to uppercase
sales_clean <- sales_clean %>%
mutate(sales_method= str_to_title(sales_method))

#Confirm the first letter of each word is uppercase using count
sales_clean %>%
count(sales_method) %>%
group_by (sales_method)
# Out:
# New names:
# • `` -> `...1`
#   sales_method n
# 1 Call         4962
# 2 Em + Call      23
# 3 Email        7466
# 4 Email + Call 2549

# %% [markdown]
# Next I need to change "Em + Call" to "Email + Call".  I can do this using str_replace from stringr

# %%
# Replace "Em + Call" with "Email + Call"
sales_clean <- sales_clean %>%
mutate(sales_method = str_replace(sales_method, "Em \\+ Call", "Email + Call"))

#Confirm transformation was made properly
sales_clean %>%
count(sales_method) %>%
group_by (sales_method)
# Out:
# New names:
# • `` -> `...1`
#   sales_method n
# 1 Call         4962
# 2 Email        7466
# 3 Email + Call 2572

# %% [markdown]
# Now that the sales_methods column is clean and a factor I can now look at the states. I am going to look at the disrtibution of states by doing a count and group by similar to what I did with sales_method

# %%
sales_clean %>%
count(state) %>%
group_by (state)
# Out:
# New names:
# • `` -> `...1`
#    state          n
# 1  Alabama         214
# 2  Alaska           40
# 3  Arizona         321
# 4  Arkansas        132
# 5  California     1872
# 6  Colorado        230
# 7  Connecticut     179
# 8  Delaware         34
# 9  Florida         904
# 10 Georgia         489
# 11 Hawaii           72
# 12 Idaho            62
# 13 Illinois        617
# 14 Indiana         354
# 15 Iowa            165
# 16 Kansas          142
# 17 Kentucky        213
# 18 Louisiana       230
# 19 Maine            63
# 20 Maryland        263
# 21 Massachusetts   294
# 22 Michigan        498
# 23 Minnesota       245
# 24 Mississippi     139
# 25 Missouri        311
# 26 Montana          45
# 27 Nebraska         91
# 28 Nevada          102
# 29 New Hampshire    53
# 30 New Jersey      434
# 31 New Mexico       84
# 32 New York        965
# 33 North Carolina  459
# 34 North Dakota     30
# 35 Ohio            566
# 36 Oklahoma        196
# 37 Oregon          229
# ...

# %% [markdown]
# All fifty states are included with no spelling errors so the states column is clean. Next I want to confirm there are no NAs in the years_as_customer column. I will do this by doing a count and group by similar to what I did with sales_method. This will also allow me to see how many customers are in each group

# %%
sales_clean %>%
count(years_as_customer) %>%
group_by (years_as_customer)
# Out:
# New names:
# • `` -> `...1`
#    years_as_customer n
# 1   0                1471
# 2   1                2504
# 3   2                1987
# 4   3                1619
# 5   4                1338
# 6   5                1118
# 7   6                 918
# 8   7                 709
# 9   8                 608
# 10  9                 509
# 11 10                 405
# 12 11                 318
# 13 12                 284
# 14 13                 239
# 15 14                 167
# 16 15                 150
# 17 16                 123
# 18 17                  88
# 19 18                  82
# 20 19                  58
# 21 20                  54
# 22 21                  37
# 23 22                  43
# 24 23                  21
# 25 24                  27
# 26 25                  19
# 27 26                  22
# 28 27                  15
# 29 28                   8
# 30 29                   5
# 31 30                   9
# 32 31                   6
# 33 32                   5
# ...

# %% [markdown]
# There is a slight problem with this data. The store was founded in 1984, therefore customers can only be a customer for 41 years. There are two customers that don't fit this criteria. Therefore they should either be exluded or their years as a customer should be changed. Because it is only 2 values out of 15,000 customers these two can be excluded. I will do this by adding in a filter clause.

# %%
#Filter out customers with year_as_customer >= 41
sales_clean <- sales_clean %>%
filter(years_as_customer <= 41)

#confirm the max number of years as a customer is 41 or less
max(sales_clean$years_as_customer)
# Out:
# [1] 39

# %% [markdown]
# Next I want to look at nb_site_visits and see if there are any off or missing values. I will do this by doing a count and group by similar to what I did with sales_method. This will also allow me to see how many customers are in each group

# %%
sales_clean %>%
count(nb_site_visits) %>%
group_by (nb_site_visits)
# Out:
# New names:
# • `` -> `...1`
#    nb_site_visits n
# 1  12                1
# 2  13                4
# 3  14                7
# 4  15               31
# 5  16               80
# 6  17              113
# 7  18              217
# 8  19              426
# 9  20              600
# 10 21              908
# 11 22             1200
# 12 23             1478
# 13 24             1600
# 14 25             1688
# 15 26             1645
# 16 27             1439
# 17 28             1175
# 18 29              893
# 19 30              654
# 20 31              371
# 21 32              250
# 22 33              114
# 23 34               51
# 24 35               33
# 25 36               14
# 26 37                5
# 27 41                1

# %% [markdown]
# Everything looks good in the nb_site_visits column. Next I will look at the nb_sold and make sure there are no missing or invalid values. I will do this by doing a count and group by similar to what I did with sales_method. This will also allow me to see how many customers are in each group.

# %%
sales_clean %>%
count(nb_sold) %>%
group_by (nb_sold)
# Out:
# New names:
# • `` -> `...1`
#    nb_sold n
# 1   7       698
# 2   8      1941
# 3   9      3535
# 4  10      3675
# 5  11      2439
# 6  12      1088
# 7  13       939
# 8  14        97
# 9  15       555
# 10 16        31

# %% [markdown]
# The nb_sold column looks good. Next I'll look at the week column and make sure there are no missing values or negative values.

# %%
sales_clean %>%
count(week) %>%
group_by (week)
# Out:
# New names:
# • `` -> `...1`
#   week n
# 1 1    3721
# 2 2    2490
# 3 3    2411
# 4 4    2574
# 5 5    2574
# 6 6    1228

# %% [markdown]
# Finally I need to look at the customer_id column and make sure there are no duplicates or null values.  I will do this by counting distinct customer_ids using n_distinct and seeing if it matches 14998. I will then filter to NA values of customer_id. If there are no matches then there are no null values

# %%
#count distinct customer_id
n_distinct(sales_clean$customer_id)

# filter by na 
sales_clean %>%
filter(is.na(customer_id))
# Out:
# [1] 14998
#      week sales_method customer_id nb_sold revenue years_as_customer
#      nb_site_visits state

# %% [markdown]
# There are 14998  distinct values in customer_id and no null values. So this field is clean.  Now lets look at some summary statistics for the entire dataset

# %%
summary (sales_clean)
# Out:
#       week       sales_method       customer_id           nb_sold
#  Min.   :1.000   Length:14998       Length:14998       Min.   : 7.00
#  1st Qu.:2.000   Class :character   Class :character   1st Qu.: 9.00
#  Median :3.000   Mode  :character   Mode  :character   Median :10.00
#  Mean   :3.098                                         Mean   :10.08
#  3rd Qu.:5.000                                         3rd Qu.:11.00
#  Max.   :6.000                                         Max.   :16.00
#
#     revenue       years_as_customer nb_site_visits     state
#  Min.   : 32.54   Min.   : 0.000    Min.   :12.00   Length:14998
#  1st Qu.: 52.47   1st Qu.: 1.000    1st Qu.:23.00   Class :character
#  Median : 89.50   Median : 3.000    Median :25.00   Mode  :character
#  Mean   : 93.94   Mean   : 4.959    Mean   :24.99
#  3rd Qu.:107.33   3rd Qu.: 7.000    3rd Qu.:27.00
#  Max.   :238.32   Max.   :39.000    Max.   :41.00
#  NA's   :1074

# %% [markdown]
# Let's visualize the distribution of revenue and the distribution of nb_sold to see if they're evenly distributed

# %%
# histogram of revenue
ggplot(sales_clean, aes(revenue))+
geom_histogram(bins=25)

#histogram of nb_sold
ggplot(sales_clean, aes(nb_sold))+
geom_histogram(bins=5)
# Out:
# Warning message:
# “Removed 1074 rows containing non-finite outside the scale range (`stat_bin()`).”
# plot without title
# plot without title

# %% [markdown]
# The revenue histogram is has several peaks and gaps, meaning the data is not evenly distributed.
#
# The nb_sold hitogram is more symmetrical, but is slighlty sckewed right.

# %% [markdown]
# Next we need to decide how we are going to handle the null values in revenue. First I'd like to see how many null values there are so I will filter to null values and count.

# %%
sales_clean %>%
filter(is.na(revenue)) %>%
count(revenue)
# Out:
#   revenue n
# 1 NA      1074

# %% [markdown]
# There are 1074 NA values in revenue. That is a significant amount so we can't exclude them. Before we impute I want to see the distribution of null values by sales_method.

# %%
sales_clean %>%
filter(is.na(revenue)) %>%
group_by(sales_method) %>%
count(revenue)
# Out:
# New names:
# • `` -> `...1`
#   sales_method revenue n
# 1 Call         NA      181
# 2 Email        NA      544
# 3 Email + Call NA      349

# %% [markdown]
# The number of null values for each sales_method isn't distributed very evenly. Therefore, I think it is best to compare the median and average for revenue that we got above to the median and average for each sales_method before deciding how to impute the missing values. I'm going to save this data in a dataframe for future reference

# %%
sales_summary <- sales_clean %>%
group_by (sales_method) %>%
summarize(median= median (revenue, na.rm=TRUE), average=mean(revenue, na.rm=TRUE))

sales_summary
# Out:
#   sales_method median average
# 1 Call          49.05  47.59687
# 2 Email         95.58  97.12767
# 3 Email + Call 184.74 183.65123

# %% [markdown]
# Before I decide if I want to use the median or average for imputation I want to plot the distribution of revenue by sales_method using ggplot2.

# %%
revenue_distribution <- ggplot(sales_clean, aes(revenue)) +
geom_histogram(bins=50) +
facet_wrap(~sales_method, nrow = 3)

revenue_distribution
# Out:
# Warning message:
# “Removed 1074 rows containing non-finite outside the scale range (`stat_bin()`).”
# plot without title

# %% [markdown]
# Because all of these are skewed we will use the medians for imputation.

# %%
#Impute medians by sales_method
sales_clean <- sales_clean %>%
group_by(sales_method) %>%
mutate(revenue= if_else(is.na(revenue), median(revenue, na.rm = TRUE), revenue)) %>%
ungroup()

#confirm no null values
sales_clean %>%
filter(is.na(revenue))
# Out:
#      week sales_method customer_id nb_sold revenue years_as_customer
#      nb_site_visits state

# %% [markdown]
# The fact that we have no results means that there are no NAs left and the column has been successfully cleaned.

# %% [markdown]
# ## 1. Validation Summary
# 	For validation each column was throughly examined and the following steps were taken:
# 	sales_method:
# 		1. Column was converted to a factor for later analysis
# 		2. Table was grouped by sales_method to obtain counts of each variable, ensure no NA values, and make 				sure the variable names were consistent
# 		4. All factors were capitalized
# 		5. The factor group "Em + Call"  was changed to "Email + Call"
#
# 	state:
# 		1. Table was grouped by state to obtain counts of each variable, ensure no NA values, and make sure the 			variable names were consistent
# 		2. All fifty states were present, spelled properly and there were no NAs so no cleaning was required
#
# 	years_as_customer:
# 		1. Structure of the column was confirmed to be numeric
# 		2. Table was group by years_as_customer to obtain counts of each variable, ensure no NA values, and make 			sure there were no impossible values (negative or greater than 41)
# 		3. The two customers that had a years_as_customer value greater than 41 were removed from the dataset
#
# 	nb_site_visits:
# 		1. Structure of the column was confirmed to be numeric
# 		2. Table was group by nb_site_visits to obtain counts of each variable, ensure no NA values, and make 			sure there were no impossible values (such as negative)
# 		3. There were no NAs or negative numbers so no cleaning was required
#
# 	nb_sold:
# 		1. Structure of the column was confirmed to be numeric
# 		2. Table was group by nb_sold to obtain counts of each variable, ensure no NA values, and make 					sure there were no impossible values (such as negative)
# 		3. There were no NAs or negative numbers so no cleaning was required
#
# 	week:
# 		1. Structure of the column was confirmed to be numeric
# 		2. Table was group by week to obtain counts of each variable, ensure no NA values, and make 					sure there were no impossible values (such as negative or greater than six)
# 		3. There were no NAs or impossible values so no cleaning was required
#
# 	customer_id:
# 		1. Ran a distinct count to ensure there were 14998 (2 values were dropped during cleaning 		  	 	years_as_customer) unique values
# 		2. There are 14998 unique IDs so no cleaning was required
#
# 	revenue:
# 		1. Structure of the column was confirmed to be numeric
# 		2. Filtered the revenue column to NAs and did a count to see how many NAs there were.
# 		3. Because there were 1074 NAs I decided to do imputation
# 		4. Summary statitstics of revenue was run excluding NAs
# 		5. Distribution of revenue by sales_method was plotted to see if imputation should be median or average
# 		6. NAs were replaced with the median of their respective sales_method

# %% [markdown]
# Now that we've imputed the missing values for revenue we can start doing some exploratory analysis. Let's start with some summary statistics.

# %%
## preform summary statistics

summary(sales_clean)
# Out:
#       week       sales_method       customer_id           nb_sold
#  Min.   :1.000   Length:14998       Length:14998       Min.   : 7.00
#  1st Qu.:2.000   Class :character   Class :character   1st Qu.: 9.00
#  Median :3.000   Mode  :character   Mode  :character   Median :10.00
#  Mean   :3.098                                         Mean   :10.08
#  3rd Qu.:5.000                                         3rd Qu.:11.00
#  Max.   :6.000                                         Max.   :16.00
#     revenue       years_as_customer nb_site_visits     state
#  Min.   : 32.54   Min.   : 0.000    Min.   :12.00   Length:14998
#  1st Qu.: 52.65   1st Qu.: 1.000    1st Qu.:23.00   Class :character
#  Median : 90.95   Median : 3.000    Median :25.00   Mode  :character
#  Mean   : 95.57   Mean   : 4.959    Mean   :24.99
#  3rd Qu.:107.75   3rd Qu.: 7.000    3rd Qu.:27.00
#  Max.   :238.32   Max.   :39.000    Max.   :41.00

# %% [markdown]
# This gives us an idea of the distribution of the numeric columns of the whole dataset.  Now let's look at if the customers are evenly distributed amongst sales methods and how many customers are in each sales_method.

# %%
#Count how many customers for each sales_method
customers_by_method<-sales_clean %>%
group_by(sales_method)%>%
count()
customers_by_method
##Visualize this
ggplot(customers_by_method, aes(sales_method, n, fill=sales_method))+
geom_bar(stat="identity")+
geom_text(aes(label=n),nudge_y= 100)
# Out:
# New names:
# • `` -> `...1`
#   sales_method n
# 1 Call         4961
# 2 Email        7465
# 3 Email + Call 2572
# plot without title

# %% [markdown]
# We can see that the number of customers in each sales_method is not the same. This is something to keep in mind when comparing sales_method.

# %% [markdown]
# Because the sales rep would like to know the distribution of revenue as a whole we will plot it.

# %%
##Create histogram of revenue 
ggplot(sales_clean, aes(revenue)) +
geom_histogram(bins=25)
# Out:
# plot without title

# %% [markdown]
# Looking at the histogram we can see that this data is not evenly distributed and is positively skewed. This means there are some extreme values that are greater than the median.

# %% [markdown]
# Next lets look at summary statistics for each sales_method, starting with revenue

# %%
#Let's start with revenue
sales_summary_revenue<- sales_clean %>%
group_by(sales_method) %>%
summarize(revenue_min=min(revenue), revenue_1st_Qu=quantile(revenue, 0.25), revenue_median=median(revenue), revenue_average=mean(revenue),revenue_3rd_Qu=quantile(revenue,0.75), revenue_max=max(revenue))

## look at the summary statistics
sales_summary_revenue
# Out:
#   sales_method revenue_min revenue_1st_Qu revenue_median revenue_average
# 1 Call          32.54       41.6300        49.05          47.64988
# 2 Email         78.83       88.3900        95.58          97.01489
# 3 Email + Call 122.11      176.4375       184.74         183.79897
#   revenue_3rd_Qu revenue_max
# 1  52.590         71.36
# 2 104.460        148.97
# 3 189.535        238.32

# %% [markdown]
# Now let's visualize these summary statistics and look at the distribution of revenue by sales_methos

# %%
##box plot of revenue by sales_method
ggplot(sales_clean, aes(sales_method, revenue, fill=sales_method))+
geom_boxplot()

## distribution of revenue by sales_method
ggplot(sales_clean, aes(revenue, fill=sales_method)) +
geom_histogram(bins=50) +
facet_wrap(~sales_method, nrow = 3)
# Out:
# plot without title
# plot without title

# %% [markdown]
# We can see that Email + Call has the widest distribution and the highest revenue while call has the smallest revenue and narrowest dirstribution.

# %% [markdown]
# Now let's create summary statistics for nb_sold

# %%
sales_clean %>%
group_by(sales_method) %>%
summarize(nb_sold_min=min(nb_sold), nb_sold_1st_Qu=quantile(nb_sold, 0.25), nb_sold_median=median(nb_sold), nb_sold_average=mean(nb_sold),nb_sold_3rd_Qu=quantile(nb_sold,0.75), nb_sold_max=max(nb_sold))
# Out:
#   sales_method nb_sold_min nb_sold_1st_Qu nb_sold_median nb_sold_average
# 1 Call         7            8             10              9.509575
# 2 Email        8            9             10              9.729270
# 3 Email + Call 8           10             12             12.225505
#   nb_sold_3rd_Qu nb_sold_max
# 1 11             14
# 2 11             15
# 3 13             16

# %% [markdown]
# Now lets visualize this data in a box plot and histogram

# %%
##box plot of nb_sold by sales_method
ggplot(sales_clean, aes(sales_method,nb_sold, fill=sales_method))+
geom_boxplot()

## distribution of nb_sold by sales_method
ggplot(sales_clean, aes(nb_sold, fill=sales_method)) +
geom_histogram(bins=5) +
facet_wrap(~sales_method, nrow = 3)
# Out:
# plot without title
# plot without title

# %% [markdown]
# We can see that Email + Call and Call are both relatively evenly distributed, with a wide distribution, while Email is right skewed and narrowly distributed.

# %% [markdown]
# Now I can do some hypothesis testing to see if there's any significant difference in sales_method and revenue or nb_sold. Let's start with revenue. Because this involves categorical data and 3 different treatment groups we cannot use the t.test or chi squared test. We will therefore use analysis of variance

# %%
AOV <- aov(sales_clean$revenue ~ sales_clean$sales_method, sales_clean)

summary(AOV)
# Out:
#                             Df   Sum Sq  Mean Sq F value Pr(>F)
# sales_clean$sales_method     2 31429066 15714533   75876 <2e-16 ***
# Residuals                14995  3105596      207
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %% [markdown]
# There is a significant difference in revenue between sales methods. To figure out which ones are significant we need run a t test on the two methods with the highest average revenue.

# %%
# Reference sales_summary to determine which groups to test
sales_summary

# run a t.test on "Email" and "Email + Call"
## first filter the data to just those two groups
ttest_data<- sales_clean %>%
filter(sales_method == "Email" | sales_method=="Email + Call")

#confirm call has been removed
ttest_data %>%
count(sales_method)



##Preform t.test
t.test(ttest_data$revenue ~ ttest_data$sales_method, data= ttest_data, lower.tail=FALSE)
# Out:
#   sales_method median average
# 1 Call          49.05  47.59687
# 2 Email         95.58  97.12767
# 3 Email + Call 184.74 183.65123
#   sales_method n
# 1 Email        7465
# 2 Email + Call 2572
# 	Welch Two Sample t-test
#
# data:  ttest_data$revenue by ttest_data$sales_method
# t = -158.47, df = 2858.5, p-value < 2.2e-16
# alternative hypothesis: true difference in means between group Email and group Email + Call is not equal to 0
# 95 percent confidence interval:
#  -87.85791 -85.71025
# sample estimates:
#        mean in group Email mean in group Email + Call
#                   97.01489                  183.79897

# %% [markdown]
# The p-value for this is below 0.05 so it is a significant difference.
#
# The best sales method in terms of revenue is to do an email and a call.

# %% [markdown]
# To help stakeholders understand the revenue created by each group let's plot a box plot of this data.

# %%
ggplot(sales_clean, aes(sales_method, revenue, fill=sales_method))+
geom_boxplot()
# Out:
# plot without title

# %% [markdown]
# In terms of revenue the Email + Call method did the best. Let's quickly plot nb_sold and renvue to see if they have a relationship.

# %%
ggplot(sales_clean, aes(nb_sold, revenue, color=sales_method))+
geom_point()
# Out:
# plot without title

# %% [markdown]
# The trend that Email + Call was most sucessful is still applicable but let's check if there's any significant difference between Email and Email + Call.

# %%
## Use the filtered dataframe, called "ttest_data", generated above and preform t.test
t.test(ttest_data$nb_sold ~ ttest_data$sales_method, data= ttest_data, lower.tail=FALSE)
# Out:
# 	Welch Two Sample t-test
#
# data:  ttest_data$nb_sold by ttest_data$sales_method
# t = -61.701, df = 3255.5, p-value < 2.2e-16
# alternative hypothesis: true difference in means between group Email and group Email + Call is not equal to 0
# 95 percent confidence interval:
#  -2.575559 -2.416912
# sample estimates:
#        mean in group Email mean in group Email + Call
#                    9.72927                   12.22551

# %% [markdown]
# Because the p value is less than 0.05 we can say there is a significant difference between the Email + Call group and the Email group in terms of both revenue and nb_sold.

# %% [markdown]
# Let's created a boxplot of nb_sold by sales_method to visualize this

# %%
ggplot(sales_clean, aes(sales_method, nb_sold, fill=sales_method))+
geom_boxplot()
# Out:
# plot without title

# %% [markdown]
# Lets further explore the data and see if years_as_customer had any significant impact on revenue or nb_sold. Lets start with revenue and graph it to see if there's any trend. Then we can run a correlation test to see if they're correlated.

# %%
#graph of years_as_customer by revenue grouped by sales_method
ggplot(sales_clean, aes(years_as_customer, revenue, color=sales_method)) +
geom_point()

##Correlation test
cor(sales_clean$years_as_customer, sales_clean$revenue)
# Out:
# [1] -0.06582881
# plot without title

# %% [markdown]
# There's no clear trend or correlation between years_as_customer and revenue, likely because there are more newer customers than older customers.
#
#
# We can also see from the colors that the years_as_customer was distributed somewhat evenly amongst the different sales methods. We can confirm it is evenly distributed with a box plot.

# %%
##box plot of years_as_customer by sales_method
ggplot(sales_clean, aes(sales_method,years_as_customer, fill=sales_method))+
geom_boxplot()
# Out:
# plot without title

# %% [markdown]
# These boxplots are all relatively the same size so we can assume that years_as_customer was evenly distributed between the different sales methods.

# %% [markdown]
# Now lets do the same for years_as_customer and nb_sold

# %%
##graph of years_as_customer and nb_sold
ggplot(sales_clean, aes(years_as_customer, nb_sold, color=sales_method)) +
geom_point()

##Correlation test
cor(sales_clean$years_as_customer, sales_clean$nb_sold)
# Out:
# [1] -0.09972786
# plot without title

# %% [markdown]
# There is no correlation or trend between years_as_customer and nb_sold.

# %% [markdown]
# Now lets graph nb_site_visits and revenue to see if there's a relationship or tend. Then let's run a correlation test

# %%
#graph of nb_site_visits by revenue grouped by sales_method
ggplot(sales_clean, aes(nb_site_visits, revenue, color=sales_method)) +
geom_point()

##Correlation test
cor(sales_clean$nb_site_visits, sales_clean$revenue)
# Out:
# [1] 0.3224914
# plot without title

# %% [markdown]
# There is no correlation between nb_site_visits and revenue.
#
# Now lets check nb_site_visits and nb_sold

# %%
#graph of nb_site_visits by nb_sold grouped by sales_method
ggplot(sales_clean, aes(nb_site_visits, nb_sold, color=sales_method)) +
geom_point()

##Correlation test
cor(sales_clean$nb_site_visits, sales_clean$nb_sold)
# Out:
# [1] 0.4907259
# plot without title

# %% [markdown]
# There is no correlation between nb_site_visits and nb_sold

# %% [markdown]
# Next lets break all the customer states into regions and see if there's any trends.

# %%
##first lets create a dataframe with states and regions according to the Census
regions_df <- data.frame(state=c("Connecticut","Maine","Massachusetts", "New Hampshire", "Rhode Island", "Vermont", "New Jersey", "New York", "Pennsylvania","Indiana", "Illinois", "Michigan", "Ohio", "Wisconsin", "Iowa", "Kansas", "Minnesota", "Missouri", "Nebraska", "North Dakota", "South Dakota","Delaware", "Florida", "Georgia", "Maryland", "North Carolina", "South Carolina", "Virginia", "West Virginia", "Alabama", "Kentucky", "Mississippi", "Tennessee", "Arkansas", "Louisiana", "Oklahoma", "Texas", "Arizona", "Colorado","Idaho", "New Mexico", "Montana", "Utah", "Nevada", "Wyoming", "Alaska", "California", "Hawaii", "Oregon", "Washington"), region=c("Northeast","Northeast","Northeast","Northeast","Northeast", "Northeast", "Northeast","Northeast", "Northeast", "Midwest", "Midwest", "Midwest", "Midwest", "Midwest", "Midwest", "Midwest","Midwest", "Midwest", "Midwest","Midwest","Midwest", "South", "South", "South", "South", "South", "South", "South", "South", "South", "South", "South", "South","South", "South","South", "South", "West", "West", "West", "West", "West", "West", "West","West", "West", "West", "West", "West", "West"))

regions_df

## Now left join regions_df to sales_clean
sales_clean_with_regions<- left_join(sales_clean, regions_df)

sales_clean_with_regions
# Out:
#    state          region
# 1  Connecticut    Northeast
# 2  Maine          Northeast
# 3  Massachusetts  Northeast
# 4  New Hampshire  Northeast
# 5  Rhode Island   Northeast
# 6  Vermont        Northeast
# 7  New Jersey     Northeast
# 8  New York       Northeast
# 9  Pennsylvania   Northeast
# 10 Indiana        Midwest
# 11 Illinois       Midwest
# 12 Michigan       Midwest
# 13 Ohio           Midwest
# 14 Wisconsin      Midwest
# 15 Iowa           Midwest
# 16 Kansas         Midwest
# 17 Minnesota      Midwest
# 18 Missouri       Midwest
# 19 Nebraska       Midwest
# 20 North Dakota   Midwest
# 21 South Dakota   Midwest
# 22 Delaware       South
# 23 Florida        South
# 24 Georgia        South
# 25 Maryland       South
# 26 North Carolina South
# 27 South Carolina South
# 28 Virginia       South
# 29 West Virginia  South
# 30 Alabama        South
# 31 Kentucky       South
# 32 Mississippi    South
# 33 Tennessee      South
# 34 Arkansas       South
# 35 Louisiana      South
# ...

# %%
# Now lets plot revenue by region 
ggplot(sales_clean_with_regions, aes(region, revenue, fill=region))+
geom_boxplot()
# Out:
# plot without title

# %% [markdown]
# There appears to be no significant difference between regions fo revenue. Lets run an analysis of variance to confirm

# %%
aov_region<- aov(sales_clean_with_regions$revenue ~ sales_clean_with_regions$region, sales_clean_with_regions)
 
summary(aov_region)
# Out:
#                                    Df   Sum Sq Mean Sq F value Pr(>F)
# sales_clean_with_regions$region     3     5823    1941   0.843   0.47
# Residuals                       14994 34528840    2303

# %% [markdown]
# There is no significant difference between regions for revenue. Let's check if there is for nb_sold

# %%
ggplot(sales_clean_with_regions, aes(region, nb_sold, fill=region))+
geom_boxplot()

#Analysis of Variance
AOV_Region<-aov(sales_clean_with_regions$nb_sold ~ sales_clean_with_regions$region, sales_clean_with_regions)
 
summary(AOV_Region)
# Out:
#                                    Df Sum Sq Mean Sq F value Pr(>F)
# sales_clean_with_regions$region     3     18   5.950   1.812  0.143
# Residuals                       14994  49241   3.284
# plot without title

# %% [markdown]
# There is also no significant difference between region and nb_sold

# %% [markdown]
# Next we need to look at if there was any difference in revenue over time for each method

# %%
sales_over_time <- sales_clean %>%
group_by(week, sales_method) %>%
summarize(total_revenue= sum(revenue), median_revenue=median(revenue), average_revenue=mean(revenue), total_nb_sold=sum(nb_sold),median_nb_sold=median(nb_sold), average_nb_sold=mean(nb_sold))


sales_over_time
# Out:
# `summarise()` has grouped output by 'week'. You can override using the
# `.groups` argument.
# New names:
# • `` -> `...1`
#    week sales_method total_revenue median_revenue average_revenue total_nb_sold
# 1  1    Call          27042.08      35.230         35.67557        5366
# 2  1    Email        247830.17      86.880         88.03914       24573
# 3  1    Email + Call  20025.91     128.915        135.31020        1281
# 4  2    Call          35263.52      43.520         43.80561        7088
# 5  2    Email        148212.57      98.830         99.80644       14942
# 6  2    Email + Call  31733.69     154.925        158.66845        2016
# 7  3    Call          37914.97      41.545         42.03433        7456
# 8  3    Email        106916.44      92.115         92.97082       10678
# 9  3    Email + Call  55203.04     150.340        153.76891        3594
# 10 4    Call          51554.57      51.190         51.34917       10249
# ...

# %% [markdown]
# Let's now graph the median revenue and median number sold by week and sales_method

# %%
#graph of revenue by week and sales_method
ggplot(sales_over_time, aes(week, median_revenue, group=sales_method, color=sales_method))+
geom_point()+
geom_line()+
labs(title="Median Revenue by Week")

#graph of nb_sold by week and sales_method
ggplot(sales_over_time, aes(week, median_nb_sold, group=sales_method, color=sales_method))+
geom_point()+
geom_line()+
labs(title="Median Number Iteams Sold by Week")
# Out:
# plot without title
# plot without title

# %% [markdown]
# We can see that the median revenue is trending upwards each week in every sales method and Email + Call the most.
#
# We can also see that the median number of items sold is trending upwards each week in every sales method, with Email + Call supassing Email week 3.

# %% [markdown]
# Lets also look at the total revenue and number of items sold for each week by sales method

# %%
#graph of revenue by week and sales_method
ggplot(sales_over_time, aes(week, total_revenue, group=sales_method, color=sales_method))+
geom_point()+
geom_line()+
labs(title="Total Revenue by Week")

#graph of nb_sold by week and sales_method
ggplot(sales_over_time, aes(week, total_nb_sold, group=sales_method, color=sales_method))+
geom_point()+
geom_line()+
labs(title="Total Number Iteams Sold by Week")
# Out:
# plot without title
# plot without title

# %% [markdown]
# We can see that week one both the number of items sold and the total revenue were highest in the email group. However both the number of items sold and the total revenue for the week is trending downwards for email and upwards until week 6 for the other 2 methods.

# %% [markdown]
# #Exploratory Analysis Summary
#
# We answered the following questions:
# 1. How many customers were there for each approach?
# 4961 customers were called, 7465 were emailed, and 2572 customers were emailed and called
#
# 2. What does the spread of the revenue look like overall? And for each method?
# The distribution of revenue overall is very wide and right skewed. The distribution for Call was the narrowest, while Email + Call  was the widest.
#
#
# 4. Was there any difference in revenue over time for each of the methods?
# Yes, in the first week Email was the most profitable, however as time went on it began to trend downwards. In constrast Email + Call and Email both trended upwards until week 6 in terms of total weekly revenue.
#
# 5. Which method do I recommend?
# Qlthough the email method takes the least amount of time, there is a significant difference in the total revenue brought in by Email + Call versus Email alone, therefore I recommend using the Email + Call method.
#
# ##Other Findings
# -There is no correlation between the number of years a customer has been a customer and revenue or the number of items sold
# - There is no correlation between the number of site visits and revenue or the number of items sold
# - There is no significant difference in revenue or number of items sold among regions

# %% [markdown]
# #Metric to Track
#  I think a good metric to track would be the median revenue by week. I think median is the best measure because it is resistent to extremes and shows a true measure of center.

# %%
#creat metric
Metric<- sales_over_time %>%
select(week, sales_method, median_revenue)

Metric
# Out:
# New names:
# • `` -> `...1`
#    week sales_method median_revenue
# 1  1    Call          35.230
# 2  1    Email         86.880
# 3  1    Email + Call 128.915
# 4  2    Call          43.520
# 5  2    Email         98.830
# 6  2    Email + Call 154.925
# 7  3    Call          41.545
# 8  3    Email         92.115
# 9  3    Email + Call 150.340
# 10 4    Call          51.190
# 11 4    Email        107.630
# 12 4    Email + Call 181.020
# 13 5    Call          52.910
# 14 5    Email        107.610
# 15 5    Email + Call 186.680
# 16 6    Call          65.875
# 17 6    Email        129.870
# 18 6    Email + Call 226.790

# %% [markdown]
# we can already predict what the median revenue for the next week will be

# %%
# Create a model from the median revenue
model<- lm(median_revenue ~ sales_method + week, data= Metric)

summary(model)

# create a data frame for prediction
week_df<-data.frame(week=c(7), sales_method=c("Call","Email", "Email + Call"))

#predict
predict<-predict(model, newdata = week_df)

predict
# Out:
# Call:
# lm(formula = median_revenue ~ sales_method + week, data = Metric)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -17.216  -7.524  -1.294   7.406  30.032
#
# Coefficients:
#                          Estimate Std. Error t value Pr(>|t|)
# (Intercept)                12.939      8.046   1.608     0.13
# sales_methodEmail          55.444      7.345   7.549 2.67e-06 ***
# sales_methodEmail + Call  123.067      7.345  16.756 1.17e-10 ***
# week                       10.125      1.756   5.767 4.88e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 12.72 on 14 degrees of freedom
# Multiple R-squared:  0.9574,	Adjusted R-squared:  0.9483
# F-statistic:   105 on 3 and 14 DF,  p-value: 7.799e-10
#         1         2         3
#  83.81717 139.26133 206.88383

# %% [markdown]
# Seventh week predictions:
# - Call= 83.82
# - Email= 139.26
# - Email + Call= 206.88

# %% [markdown]
# # Final Summary
#
#  Emailing the customer than following up with a phone call yielded significantly better results in terms of both revenue and number of items sold than email alone. Calling alone is not only the most time consuming method, but it also had the lowest revenue and number of items sold.
#
# Based off this I would focus on the Email + Call method.
#
# Both number of items sold and total revenue decrease during week six. I recommend a follow up call or email to see if that increases sales.
#
# Another recommendation I have is to ensure datasets are properly cleaned and valid. There were over 1000 NA values in revenue, which could've impacted my analysis. Ensuring datasets are complete is crucial to proper analysis.
